# %%
# Population described by linear function using only continuous variables
# study1
# %run Main.py
# Out:
# Choose which regression function to test (linear or polynomial): linear
# Choose variable type: continuous or hybrid: continuous
# Choose which study to run (study1, study2, study3 or study4): study1
# Simulation of distribution change of input variables, including Linear Regression,         Random Forest Regression and Gradient Boosting Regression on  100000 artificially         generated observations for each of  10 years is finished.

# %%
# Population described by linear function using both continuous and binary variables
# study1
# %run Main.py
# Out:
# Choose which regression function to test (linear or polynomial): linear
# Choose variable type: continuous or hybrid: hybrid
# Choose which study to run (study1, study2, study3 or study4): study1
# Simulation of distribution change of input variables, including Linear Regression,         Random Forest Regression and Gradient Boosting Regression on  100000 artificially         generated observations for each of  10 years is finished.

# %%
# Population described by linear function using only continuous variables
# study2
# %run Main.py
# Out:
# Choose which regression function to test (linear or polynomial): linear
# Choose variable type: continuous or hybrid: continuous
# Choose which study to run (study1, study2, study3 or study4): study2
# Simulation of relationship change between input variables, including Linear Regression,         Random Forest Regression and Gradient Boosting Regression on 100000 artificially         generated observations for each of 10 years is finished.

# %%
# Population described by linear function using both continuous and binary variables
# study2
# %run Main.py
# Out:
# Choose which regression function to test (linear or polynomial): linear
# Choose variable type: continuous or hybrid: hybrid
# Choose which study to run (study1, study2, study3 or study4): study2
# Simulation of relationship change between input variables, including Linear Regression,         Random Forest Regression and Gradient Boosting Regression on 100000 artificially         generated observations for each of 10 years is finished.

# %%
# Population described by linear function using only continuous variables
# study3
# %run Main.py
# Out:
# Choose which regression function to test (linear or polynomial): linear
# Choose variable type: continuous or hybrid: continuous
# Choose which study to run (study1, study2, study3 or study4): study3
# Simulation of mean change of the dependent variable, including Linear Regression,         Random Forest Regression and Gradient Boosting Regression on 100000 artificially         generated observations for each of 10 years is finished.

# %%
# Population described by linear function using both continuous and binary variables
# study3
# %run Main.py
# Out:
# Choose which regression function to test (linear or polynomial): linear
# Choose variable type: continuous or hybrid: hybrid
# Choose which study to run (study1, study2, study3 or study4): study3
# Simulation of mean change of the dependent variable, including Linear Regression,         Random Forest Regression and Gradient Boosting Regression on 100000 artificially         generated observations for each of 10 years is finished.

# %%
# Population described by linear function using only continuous variables
# study4
# %run Main.py
# Out:
# Choose which regression function to test (linear or polynomial): linear
# Choose variable type: continuous or hybrid: continuous
# Choose which study to run (study1, study2, study3 or study4): study4
# Simulation of Concept Drift, including Linear Regression,         Random Forest Regression and Gradient Boosting Regression on  100000 artificially         generated observations for each of  10 years is finished.

# %%
# Population described by linear function using both continuous and binary variables
# study4
# %run Main.py
# Out:
# Choose which regression function to test (linear or polynomial): linear
# Choose variable type: continuous or hybrid: hybrid
# Choose which study to run (study1, study2, study3 or study4): study4
# Simulation of Concept Drift, including Linear Regression,         Random Forest Regression and Gradient Boosting Regression on  100000 artificially         generated observations for each of  10 years is finished.
